# %%
#Cargamos el dataset
import pandas as pd 
import matplotlib.pyplot as plt
spotify_2023 = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')
spotify_2023.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
#Info y Columnas para ver por donde empezamos
spotify_2023.info()
spotify_2023.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
#borramos las fechas, por ahora
spotify_2023 = spotify_2023.drop(['released_month', 'released_day'], axis=1)

# %%
#juntamos a las canciones por artistas
#top20
canciones_por_artista = spotify_2023['artist(s)_name'].value_counts()
canciones_por_artista.head(20)
# Out:
# artist(s)_name
# Taylor Swift        34
# The Weeknd          22
# Bad Bunny           19
# SZA                 19
# Harry Styles        17
# Kendrick Lamar      12
# Morgan Wallen       11
# Ed Sheeran           9
# BTS                  8
# Feid                 8
# Drake, 21 Savage     8
# Labrinth             7
# Olivia Rodrigo       7
# NewJeans             6
# Doja Cat             6
# Billie Eilish        5
# Drake                4
# IVE                  4
# Arctic Monkeys       4
# Karol G              4
# Name: count, dtype: int64

# %%
#La columna streams a pesar de ser números aparecen como object, la cambiamos a int64

spotify_2023['streams'] = pd.to_numeric(spotify_2023['streams'], errors='coerce').astype('Int64')

# %%
#ordenamos por streams
#hacemos top 20
spotify_2023_streams = spotify_2023.sort_values(by='streams', ascending=False)
stream_top = spotify_2023_streams.head(20)
stream_top.head()
# Out:
#                                         track_name         artist(s)_name  \
# 55                                 Blinding Lights             The Weeknd
# 179                                   Shape of You             Ed Sheeran
# 86                               Someone You Loved          Lewis Capaldi
# 620                                   Dance Monkey            Tones and I
# 41   Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
#
#      artist_count  released_year  in_spotify_playlists  in_spotify_charts  \
# 55              1           2019                 43899                 69
# 179             1           2017                 32181                 10
# 86              1           2018                 17836                 53
# 620             1           2019                 24529                  0
# 41              2           2018                 24094                 78
#
# ...

# %%
#Juntamos todos los streams por artista
streams_por_artista = spotify_2023.groupby('artist(s)_name')['streams'].sum()

# Ordenar los resultados de mayor a menor
streams_por_artista = streams_por_artista.sort_values(ascending=False)

# Mostrar los primeros 10 resultados
streams_por_artista.head(10)
# Out:
# artist(s)_name
# The Weeknd         14185552870
# Taylor Swift       14053658300
# Ed Sheeran         13908947204
# Harry Styles       11608645649
# Bad Bunny           9997799607
# Olivia Rodrigo      7442148916
# Eminem              6183805596
# Bruno Mars          5846920599
# Arctic Monkeys      5569806731
# Imagine Dragons     5272484650
# Name: streams, dtype: Int64

# %%
top_20_stream= streams_por_artista.head(20)
plt.figure(figsize=(15, 6))
top_20_stream.plot(kind='bar', color='blue')
plt.title('Streamings por artista')
plt.xlabel('Artista(s)')
plt.ylabel('Streams')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('top_20_streamings.png')
plt.show()

# %%
spotify_2023_playlists = spotify_2023.sort_values(by='in_spotify_playlists', ascending=False)
spotify_2023_playlists.head()
# Out:
#                                     track_name  \
# 757                     Get Lucky - Radio Edit
# 630                             Mr. Brightside
# 720                    Wake Me Up - Radio Edit
# 624  Smells Like Teen Spirit - Remastered 2021
# 199                                 Take On Me
#
#                                  artist(s)_name  artist_count  released_year  \
# 757  Pharrell Williams, Nile Rodgers, Daft Punk             3           2013
# 630                                 The Killers             1           2003
# 720                                      Avicii             1           2013
# 624                                     Nirvana             1           1991
# 199                                        a-ha             1           1984
#
#      in_spotify_playlists  in_spotify_charts     streams  in_apple_playlists  \
# 757                 52898                  0   933815613                 203
# ...

# %%
spotify_2023_apple = spotify_2023.sort_values(by='in_apple_playlists', ascending=False)
spotify_2023_apple.head()
# Out:
#                     track_name                artist(s)_name  artist_count  \
# 55             Blinding Lights                    The Weeknd             1
# 403   One Kiss (with Dua Lipa)       Calvin Harris, Dua Lipa             2
# 620               Dance Monkey                   Tones and I             1
# 407            Don't Start Now                      Dua Lipa             1
# 84   STAY (with Justin Bieber)  Justin Bieber, The Kid Laroi             2
#
#      released_year  in_spotify_playlists  in_spotify_charts     streams  \
# 55            2019                 43899                 69  3703895074
# 403           2017                 27705                 10  1897517891
# 620           2019                 24529                  0  2864791672
# 407           2019                 27119                  0  2303033973
# 84            2021                 17050                 36  2665343922
#
#      in_apple_playlists  in_apple_charts in_deezer_playlists  ...  bpm key  \
# ...

# %%
import seaborn as sns
selected_columns = ["streams", "danceability_%", "valence_%", "energy_%", "acousticness_%", "instrumentalness_%", "liveness_%", "speechiness_%"]
subset_df = spotify_2023[selected_columns]

# Calcular la matriz de correlación
correlation_matrix = subset_df.corr()

# Crear el heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="viridis", linewidths=.5)
plt.title('Correlación entre Streams y Características de la Canción')
plt.savefig('heatmap.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="key", data=spotify_2023, palette="viridis")
plt.title("Cantidad de Canciones por Tono")
plt.xlabel("Tono")
plt.ylabel("Número de Canciones")
plt.grid(True)
plt.savefig("Key")
plt.show()
# Out:
# C:\Users\tomuz\AppData\Local\Temp\ipykernel_1820\4060915840.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="key", data=spotify_2023, palette="viridis")

# %% [markdown]
# plt.figure(figsize=(10, 6))
# sns.countplot(x="key", data=spotify_2023, palette="viridis")
# plt.title("Cantidad de Canciones por Tono")
# plt.xlabel("Tono")
# plt.ylabel("Número de Canciones")
# plt.grid(True)
# plt.savefig("Key")
# plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="mode", data=spotify_2023, palette="viridis")
plt.title("Cantidad de Canciones por Tono")
plt.xlabel("Tono")
plt.ylabel("Número de Canciones")
plt.grid(True)
plt.savefig("mode")
plt.show()
# Out:
# C:\Users\tomuz\AppData\Local\Temp\ipykernel_1820\466809856.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="mode", data=spotify_2023, palette="viridis")

# %%
top_20_stream.head()
# Out:
# artist(s)_name
# The Weeknd      14185552870
# Taylor Swift    14053658300
# Ed Sheeran      13908947204
# Harry Styles    11608645649
# Bad Bunny        9997799607
# Name: streams, dtype: Int64

# %%
#un error tipico es que se pase en el numero de bom por lo que todo por encima de 140 lo vamos a difivir a la mitad
spotify_2023["bpm"] = spotify_2023["bpm"].apply(lambda x: x / 2 if x > 140 else x)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x="bpm", data=spotify_2023, palette="viridis")
plt.title("Distribución de BPM en Canciones")
plt.xlabel("BPM (Beats per Minute)")
plt.grid(True)
plt.savefig("boxplotbpm.png")
plt.show()
# Out:
# C:\Users\tomuz\AppData\Local\Temp\ipykernel_1820\2432632312.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="bpm", data=spotify_2023, palette="viridis")

# %%
spotimetrics = ["streams", "danceability_%", "valence_%", "energy_%", "acousticness_%", "instrumentalness_%", "liveness_%", "speechiness_%", "track_name"]
subset_df = stream_top[spotimetrics]

# Establecer 'artist' como índice para facilitar la visualización
subset_df.set_index('track_name', inplace=True)

# Ordenar el DataFrame por cada columna de manera ascendente
subset_df.sort_values(by=subset_df.columns.tolist(), inplace=True)

# Crear un gráfico de barras apiladas
for column in subset_df.columns:
    plt.figure(figsize=(10, 6))
    subset_df[[column]].plot(kind='bar', stacked=True)
    plt.title(f'{column} por Artista')
    plt.xlabel('Artista')
    plt.ylabel('Porcentaje')
    plt.legend().set_visible(False)  # Ocultar la leyenda para mejorar la visualización
    plt.show()
# Out:
# C:\Users\tomuz\AppData\Local\Temp\ipykernel_13516\1095809111.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df.sort_values(by=subset_df.columns.tolist(), inplace=True)
